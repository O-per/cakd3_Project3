# %%
# 트랜스포머 버전 맞추기
# !pip install transformers==4.3.2
# 버전 맞추기
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# %cd /content/drive/MyDrive/test_et5_finetune/finetune-t5-booksummary
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 1.8 MB 4.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 48.4 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 48.2 MB/s
# ...
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |█████████████▌                  | 834.1 MB 1.2 MB/s eta 0:15:23tcmalloc: large alloc 1147494400 bytes == 0x559ce21aa000 @  0x7fe457445615 0x559ca94774cc 0x559ca955747a 0x559ca947a2ed 0x559ca956be1d 0x559ca94ede99 0x559ca94e89ee 0x559ca947bbda 0x559ca94edd00 0x559ca94e89ee 0x559ca947bbda 0x559ca94ea737 0x559ca956cc66 0x559ca94e9daf 0x559ca956cc66 0x559ca94e9daf 0x559ca956cc66 0x559ca94e9daf 0x559ca947c039 0x559ca94bf409 0x559ca947ac52 0x559ca94edc25 0x559ca94e89ee 0x559ca947bbda 0x559ca94ea737 0x559ca94e89ee 0x559ca947bbda 0x559ca94e9915 0x559ca947bafa 0x559ca94e9c0d 0x559ca94e89ee
# ...

# %%
# !pip install flask-ngrok
# !pip install flask==0.12.2 
# !pip install bert-score
# Out:
# ...
#      |████████████████████████████████| 83 kB 1.3 MB/s
# ...
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
# ...
#      |████████████████████████████████| 59 kB 3.0 MB/s
# ...

# %%
# 런타임 재시작 후 현재 디렉토리 변경
# %cd /content/drive/MyDrive/ngrok-ssh
# Out:
# /content/drive/MyDrive/ngrok-ssh

# %%
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 745 kB 4.1 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=18990 sha256=4b72c475fc408eeff7552dd12ae2698871e78b96adc280c0f089d2522cb8ed48
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# ...

# %%
import getpass

from pyngrok import ngrok, conf

print("Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth")
conf.get_default().auth_token = getpass.getpass()

# Open a TCP ngrok tunnel to the SSH server
connection_string = ngrok.connect(22, "tcp").public_url

ssh_url, port = connection_string.strip("tcp://").split(":")
print(f" * ngrok tunnel available, access with `ssh root@{ssh_url} -p{port}`")
# Out:
# Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth
# ··········
#  * ngrok tunnel available, access with `ssh root@2.tcp.ngrok.io -p18543`

# %%
# !ngrok authtoken #ngrok account authtoken key 입력#
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# helloflask_colab.py 위치한 경로로 현재 경로 바꾸기
# %cd /content/drive/MyDrive/cakd3/3차 프로젝트/2팀/코드/서비스구현
# Out:
# /content/drive/.shortcut-targets-by-id/1gYntduLiiTOoflqDhdrKbvFrha_4o7jY/cakd3/3차 프로젝트/2팀/코드/서비스구현

# %%
# 실행
# !python helloflask_colab.py
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with inotify reloader
#  * Running on http://a4bb-35-201-142-1.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
#  * Debugger is active!
#  * Debugger PIN: 907-563-466
# Your account 'Seul Yi' is limited to 1 simultaneous ngrok client session.
# Active ngrok client sessions in region 'us':
#   - ts_21zb5w17M1lhQjSWi58oMzmXWhq (35.201.142.1)
#
# ERR_NGROK_108
#
#  * Running on http://a4bb-35-201-142-1.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [08/Dec/2021 06:58:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2021 06:58:27] "GET /static/css/main.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2021 06:58:29] "GET /static/images/pic2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2021 06:58:30] "GET /static/images/random.png HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2021 06:58:30] "GET /static/images/topic_w.png HTTP/1.1" 200 -
# ...

# %%
import os

from http.server import HTTPServer, BaseHTTPRequestHandler
from pyngrok import ngrok

port = os.environ.get("PORT", 80)

server_address = ("", port)
httpd = HTTPServer(server_address, BaseHTTPRequestHandler)

public_url = ngrok.connect(port).public_url
print("ngrok tunnel \"{}\" -> \"http://127.0.0.1:{}\"".format(public_url, port))

try:
    # Block until CTRL-C or some other terminating event
    httpd.serve_forever()
except KeyboardInterrupt:
   print(" Shutting down server.")

   httpd.socket.close()

# %%
httpd.socket.close()
